# %% [markdown]
# # Teach Your Laptop to Trade Stock Options.
# # Notebook 3: Train Machine Learners.
# What could possibly go wrong?
#
# 6/10/2020
#
# Internal notes - This is the live branch from OptionsTrainLearners_D1.ipynb. Develop this one, not _D1.
#
# Added XGBoost. Works!

# %% [markdown]
# ## Purpose of this Notebook - Train Learners to trade stock options.
# This notebook is the second in a series of notebooks that illustrate how to train a Machine learner to trade stock options, successfully, we hope. This notebook demonstrates how to train several Learners and compare them to choose the best one for your specific project. This notebook uses a data set of stock option trades for ExxonMobil (XOM) from 2017-2018 to illustrate many aspects of Machine Learning with the python SKLearn library. All the trades are short covered calls.
#
# What You Need: Basic knowledge of Python, pandas, numpy, dataframes, and statistics.
#
# What You Don't Need: Knowledge of stock options, scipy, sklearn, or Machine Learning. This project is self-contained and you will learn as you go.
#
# You will Learn:
#
# - How to display features for visual evaluation of feature quality.
# - How to set up several Learners for comparison on your feature set.
# - How to capture performance data and execution time data for comparison.
# - How to display comparison data for visual inspection.

# %% [markdown]
# ## 1. Explore the Feature Set.

# %% [markdown]
# Load the csv file training_features.csv into a dataframe.
#
# Although you do not need any konwledge of stock options, or even finance, to use this notebook, a little information may make it more interesting.
#
# Column Name Abbreviations
# - STO - 'Sell to Open.' A trader may sell or buy a put or call contract to open a trade.
# - ARR - 'Annual Return Rate.' The equivalent rate of return on the trade, if it expires, on an annual basis.
# - strike_delta% - The difference between the stock price and the option strike price (the delta) as a % of stock price.
# - days long - The number of days from the trade date to the expiry date.
#
# Evaluation Questions:
# - Do think these features are sufficient to predict the profitability of this type of option trade? Why, why not?
# - What other features would you add to this feature set?
# - How will you evaluate feature quality and contribbution to the results?
#
# Code Questions:
# - How many features are in this feature set?
# - What is the data type of each feature?
# - What are the statistics of each feature? Get the min, max, mean, and standard deviation of each.

# %%
import pandas as pd
import numpy as np
training_features = pd.DataFrame()
training_features = pd.read_csv('training_features_wlabel.csv', index_col = False)
print(training_features.head(5))
print(training_features.columns.to_list())
# Out:
#    Unnamed: 0  stock_price_at_STO_offer  STO_strike  STO_days_long  \
# 0           0                     81.82        80.0           11.0
# 1           1                     81.81        80.0           11.0
# 2           2                     81.82        80.5           11.0
# 3           3                     81.81        80.5           11.0
# 4           4                     82.10        80.5           11.0
#
#    STO_offer_ARR  stock_price_at_open  STO_ask_fee%  STO_offer_strike_delta%  \
# 0       0.786760                82.10      0.023711                -0.022244
# 1       0.784828                82.10      0.023652                -0.022124
# 2       0.618458                82.10      0.018638                -0.016133
# 3       0.608394                82.10      0.018335                -0.016013
# 4       0.701224                82.14      0.021133                -0.019488
#
#    Closed_xtn_Profit$  Closed_xtn_Profit%  ...        MFI     MACD  \
# 0              -610.0           -0.316062  ...  51.016173 -0.20322
# 1              -615.0           -0.319481  ...  51.016173 -0.20322
# 2              -525.0           -0.346535  ...  51.016173 -0.20322
# 3              -550.0           -0.369128  ...  51.016173 -0.20322
# 4              -315.0           -0.182609  ...  51.016173 -0.20322
#
#    45 day vel  30 day vel  15 day vel  10 day vel  5 day vel  2 day vel  \
# 0   -0.009706   -0.026812   -0.123964    0.055939      0.061       0.39
# 1   -0.009706   -0.026812   -0.123964    0.055939      0.061       0.39
# 2   -0.009706   -0.026812   -0.123964    0.055939      0.061       0.39
# 3   -0.009706   -0.026812   -0.123964    0.055939      0.061       0.39
# 4   -0.009706   -0.026812   -0.123964    0.055939      0.061       0.39
#
#    ER - Expiry  label
# 0         80.0      0
# 1         80.0      0
# 2         80.0      0
# 3         80.0      0
# 4         80.0      0
#
# [5 rows x 32 columns]
# ['Unnamed: 0', 'stock_price_at_STO_offer', 'STO_strike', 'STO_days_long', 'STO_offer_ARR', 'stock_price_at_open', 'STO_ask_fee%', 'STO_offer_strike_delta%', 'Closed_xtn_Profit$', 'Closed_xtn_Profit%', '45 day SMA', '30 day SMA', '15 day SMA', '10 day SMA', 'Yearly Min', 'Yearly Max', '1 days old', '2 days old', '3 days old', '4 days old', '5 days old', 'RSI', 'MFI', 'MACD', '45 day vel', '30 day vel', '15 day vel', '10 day vel', '5 day vel', '2 day vel', 'ER - Expiry', 'label']

# %% [markdown]
# ## 2. Visualize the Feature Set

# %% [markdown]
# With Matplotlib, compare the features when grouped by proitable trades ('winners' with label = 1) vs. unprofitable trades ('losers' with label = 0).

# %%
import matplotlib
import matplotlib.pyplot as plt

opt_sample = pd.read_csv('opt_sample.csv', index_col = 0)
print(opt_sample.shape)
#print(opt_sample.head(5))
fig,axes =plt.subplots(10,3, figsize=(12, 15)) # 3 columns each containing 9 figures, total 27 features
winners = opt_sample[opt_sample['label']==1]    # define winners
losers  = opt_sample[opt_sample['label']==0]    # define losers

winners = winners.to_numpy()
losers  = losers.to_numpy()
opt_np = opt_sample.to_numpy()

ax=axes.ravel()# flat axes with numpy ravel

print('setting up bins.') 
for i in range(len(opt_sample.columns.values)):
  _,bins=np.histogram(opt_np[:,i],bins=40)
  
  ax[i].hist(losers[:,i],bins=bins,color='r',alpha=.5)# red color for malignant class
  ax[i].hist(winners[:,i],bins=bins,color='g',alpha=0.3)# alpha is           for transparency in the overlapped region
  ax[i].set_title(opt_sample.columns.values[i],fontsize=9)
  ax[i].axes.get_xaxis().set_visible(False) # the x-axis co-ordinates are not so useful, as we just want to look how well separated the histograms are
  ax[i].set_yticks(())
ax[0].legend(['losers','winners'],loc='best',fontsize=8)
plt.tight_layout()# let's make good plots
plt.show()
# Out:
# (5577, 29)
# setting up bins.

# %% [markdown]
# Each chart above shows a collection of green bars and red bars for a single feature.
#
# Evaluation Questions:
#  - What is the meaning of the green bars and red bars?
#  - By looking at the charts, can you identify which features contain more information to train the Learners? How? Why?
#  - Which chart shows perfect separation between the red and green bars. Why?
#  - Can we use this feature to train the Learners? Why, why not?
#  - In your opinion, can we train the Learners effectively with this set of features? Why, why not?
#
#  Code Questions:
#  - Develop a single metric that defines the relationship between red and greed data points for each feature.
#  - Compare your metric to the charts. Does your metric provide additional insight? Why, why not.
#  - Calculate the correlation matrix of all the features. Hint, this is a single line of code with a dataframe.
#  - Rank the features with the highest correlation, then plot the correlation as a series of charts. Any benefit?
#  - Rank the correlation of each feature with the label, then plot. Any additional benefit?
#
# The correlation analysis is one method to perform feature reduction or elimination, which is a key component in feature development. The next notebook in this series shows several techniques to do feature elimination.

# %% [markdown]
# ## 3. Write the Function to Test Different Classifiers.

# %% [markdown]
# Review the function to train, test, and measure different Learners. Review the online documentation for the SKLearn library and read about each of these Learners.
#
# Evaluation Questions:
#  - What is a regressor? a classifier? Which should we use for this project as set up? Why?
#  - How would we change the setup to use the other type? Which would be better? Why?
#  - Describe each Learner in your own words. Which ones do you think will work best for this project? Why?
#  - RandomForest and AdaBoost are called "ensemble learners." Why?
#
# Code Questions:
#  - When you execute the code block below, what output do you expect to see? Why? This is a trick question.
#  - How will you add another Learner to the evaluation set? OK, then do it.

# %%
# Import ML Libraries from SKLearn.

from sklearn import svm
from sklearn import metrics
from sklearn.decomposition     import PCA
from sklearn.preprocessing     import StandardScaler
from sklearn.neighbors         import KNeighborsClassifier
from sklearn.neural_network    import MLPClassifier
from sklearn.ensemble          import RandomForestClassifier, AdaBoostClassifier
from sklearn.datasets          import make_classification
from sklearn.neighbors         import KNeighborsClassifier
from sklearn.neural_network    import MLPClassifier
from sklearn.naive_bayes       import GaussianNB 
from sklearn.feature_selection import SelectKBest
import xgboost
from xgboost                   import XGBClassifier
import catboost
from catboost                  import CatBoostClassifier
from sklearn.feature_selection import chi2
from sklearn.metrics           import accuracy_score

import time
import random

def RunLearners(Xr_train, Xr_test, yr_train, yr_test, all_run_stats, run_ID):
   print() 
   print('Please be patient. Some of these Learners are pretty slow learners.')
   print('If you get impatient, put in a print statement to show progress, or just use one already in place.')
   print()
    
   this_run_stats = pd.DataFrame()
   
   learners = {#'RandomForest_d6'  : RandomForestClassifier(max_depth=3, random_state=97),
               'RandomForest_d12' : RandomForestClassifier(max_depth=12, random_state=97),
               'KNNeighbors_2'    : KNeighborsClassifier(n_neighbors=3),
               #'KNNeighbors_8'    : KNeighborsClassifier(n_neighbors=8),
               'MLPerceptron'     : MLPClassifier(alpha=1, max_iter=1000),
               'SVC linear'       : svm.SVC(kernel = 'linear'),
               #'SVC poly'         : svm.SVC(kernel = 'poly'),
               #'GaussianNB'       : GaussianNB(),
               'AdaBoost'         : AdaBoostClassifier(),
               'XGBoost'          : XGBClassifier(),
               'CatBoost'         : CatBoostClassifier()
               #'SVC sigmoid'      : svm.SVC(kernel = 'sigmoid')
               }

   learner_types = learners.keys()
   for learner in learner_types:
      clf = learners[learner]
      start_time = time.time()  
      clf.fit(Xr_train, yr_train)
      end_time = time.time()
      train_time = end_time - start_time
      start_time = time.time()  
      yr_pred = clf.predict(X_test)
      end_time = time.time()
      predict_time = end_time - start_time
        
      #print()
      #print('for learner ', learner)
      #print(learner, ' accuracy      = ', metrics.accuracy_score(yr_test, yr_pred))
      #print(learner, ' avg. precison = ', metrics.average_precision_score(yr_test, yr_pred))

      this_run_stats.loc[learner, 'Accuracy']     = metrics.accuracy_score(yr_test, yr_pred)
      this_run_stats.loc[learner, 'Precision']    = metrics.average_precision_score(yr_test, yr_pred)
      this_run_stats.loc[learner, 'Train time']   = train_time
      this_run_stats.loc[learner, 'Predict time'] = predict_time

   this_run_stats['run_ID'] = run_ID
   all_run_stats = all_run_stats.append(this_run_stats)
   return all_run_stats
   print('all_run_stats = ')
   print(all_run_stats) 

print()
print('No output yet. Call this function with a set of train and test features.')
print('Then run the code block below to prepare a set of train and test data, then call the function RunLearners')
print('to execute each of the Learners and collect performance metrics.')
# Out:
# No output yet. Call this function with a set of train and test features.
# Then run the code block below to prepare a set of train and test data, then call the function RunLearners
# to execute each of the Learners and collect performance metrics.

# %% [markdown]
# ## 4. Investigate the train and test data sets.
# Run the code block below, then consider these questions.
#
# Evaluation Questions:
# - Explain the differences between X_train, y_train, X_test, and y_test.
# - What are the dimensions of each?
# - What is the purpose of each?
# - What is the difference between a numpy array and a dataframe? Which works with a Learner?
# - How does the code modify X_train? Why?

# %%
# Prepare the test and train data sets.

X_train = pd.DataFrame()
y_train = pd.DataFrame()
X_test  = pd.DataFrame()
y_test  = pd.DataFrame()

learner_stats = pd.DataFrame()

X_train  = pd.read_csv('opt_sample.csv', index_col = 0)

#print(X_train.head(10))
y_train = X_train[['label']].to_numpy()
y_train = y_train.ravel()
print('y_train shape = ', y_train.shape)
X_train.drop(labels = 'label', axis = 'columns', inplace = True)
print('X_train shape = ', X_train.shape)

X_test = pd.read_csv('opt_test.csv', index_col = 0)
y_test = X_test[['label']].to_numpy()
X_test.drop(labels = 'label', axis = 'columns', inplace = True)

y_train = np.ravel(y_train)
y_test  = np.ravel(y_test)
#print('y_train = ', y_train)
#print('y_test = ', y_test)

run_ID = 'Initial'
learner_stats = RunLearners(X_train, X_test, y_train, y_test, learner_stats, run_ID)
print(learner_stats)
learner_stats.to_csv('learner_stats.csv')
# Out:
# y_train shape =  (5577,)
# X_train shape =  (5577, 28)
#
# Please be patient. Some of these Learners are pretty slow learners.
# If you get impatient, put in a print statement to show progress, or just use one already in place.
#
# Learning rate set to 0.021461
# 0:	learn: 0.6723207	total: 109ms	remaining: 1m 49s
# 1:	learn: 0.6533127	total: 122ms	remaining: 1m
# 2:	learn: 0.6344295	total: 134ms	remaining: 44.6s
# 3:	learn: 0.6148469	total: 145ms	remaining: 36.1s
# 4:	learn: 0.6015248	total: 156ms	remaining: 31s
# 5:	learn: 0.5892385	total: 172ms	remaining: 28.5s
# 6:	learn: 0.5715064	total: 193ms	remaining: 27.4s
# 7:	learn: 0.5525373	total: 208ms	remaining: 25.8s
# 8:	learn: 0.5372496	total: 224ms	remaining: 24.7s
# 9:	learn: 0.5250370	total: 236ms	remaining: 23.4s
# 10:	learn: 0.5116350	total: 248ms	remaining: 22.3s
# 11:	learn: 0.4990179	total: 259ms	remaining: 21.3s
# 12:	learn: 0.4879750	total: 269ms	remaining: 20.4s
# 13:	learn: 0.4782065	total: 280ms	remaining: 19.7s
# 14:	learn: 0.4716090	total: 291ms	remaining: 19.1s
# 15:	learn: 0.4618528	total: 302ms	remaining: 18.6s
# 16:	learn: 0.4544157	total: 313ms	remaining: 18.1s
# 17:	learn: 0.4461454	total: 324ms	remaining: 17.7s
# 18:	learn: 0.4403198	total: 339ms	remaining: 17.5s
# 19:	learn: 0.4342483	total: 355ms	remaining: 17.4s
# 20:	learn: 0.4262003	total: 367ms	remaining: 17.1s
# 21:	learn: 0.4207304	total: 379ms	remaining: 16.8s
# 22:	learn: 0.4152427	total: 390ms	remaining: 16.6s
# 23:	learn: 0.4084594	total: 403ms	remaining: 16.4s
# 24:	learn: 0.4018618	total: 415ms	remaining: 16.2s
# 25:	learn: 0.3961180	total: 429ms	remaining: 16.1s
# 26:	learn: 0.3918894	total: 442ms	remaining: 15.9s
# 27:	learn: 0.3873458	total: 453ms	remaining: 15.7s
# 28:	learn: 0.3837136	total: 464ms	remaining: 15.5s
# 29:	learn: 0.3788302	total: 475ms	remaining: 15.4s
# 30:	learn: 0.3747233	total: 486ms	remaining: 15.2s
# 31:	learn: 0.3717102	total: 497ms	remaining: 15s
# 32:	learn: 0.3664611	total: 510ms	remaining: 15s
# 33:	learn: 0.3628414	total: 528ms	remaining: 15s
# 34:	learn: 0.3594727	total: 539ms	remaining: 14.9s
# 35:	learn: 0.3569199	total: 551ms	remaining: 14.7s
# 36:	learn: 0.3536490	total: 562ms	remaining: 14.6s
# 37:	learn: 0.3501414	total: 573ms	remaining: 14.5s
# 38:	learn: 0.3474104	total: 584ms	remaining: 14.4s
# 39:	learn: 0.3448717	total: 594ms	remaining: 14.3s
# 40:	learn: 0.3424964	total: 605ms	remaining: 14.2s
# 41:	learn: 0.3384886	total: 616ms	remaining: 14.1s
# 42:	learn: 0.3332044	total: 627ms	remaining: 14s
# 43:	learn: 0.3292395	total: 638ms	remaining: 13.9s
# 44:	learn: 0.3269691	total: 649ms	remaining: 13.8s
# 45:	learn: 0.3223888	total: 660ms	remaining: 13.7s
# 46:	learn: 0.3190059	total: 676ms	remaining: 13.7s
# 47:	learn: 0.3154830	total: 692ms	remaining: 13.7s
# 48:	learn: 0.3125011	total: 706ms	remaining: 13.7s
# 49:	learn: 0.3102046	total: 717ms	remaining: 13.6s
# 50:	learn: 0.3077478	total: 728ms	remaining: 13.6s
# 51:	learn: 0.3043328	total: 739ms	remaining: 13.5s
# 52:	learn: 0.3008941	total: 750ms	remaining: 13.4s
# 53:	learn: 0.2973601	total: 761ms	remaining: 13.3s
# 54:	learn: 0.2944218	total: 772ms	remaining: 13.3s
# 55:	learn: 0.2923218	total: 783ms	remaining: 13.2s
# 56:	learn: 0.2886281	total: 794ms	remaining: 13.1s
# 57:	learn: 0.2874260	total: 806ms	remaining: 13.1s
# 58:	learn: 0.2852121	total: 819ms	remaining: 13.1s
# 59:	learn: 0.2826174	total: 833ms	remaining: 13s
# 60:	learn: 0.2811589	total: 848ms	remaining: 13s
# 61:	learn: 0.2793532	total: 865ms	remaining: 13.1s
# 62:	learn: 0.2772563	total: 879ms	remaining: 13.1s
# 63:	learn: 0.2751634	total: 890ms	remaining: 13s
# 64:	learn: 0.2740299	total: 902ms	remaining: 13s
# 65:	learn: 0.2716142	total: 913ms	remaining: 12.9s
# 66:	learn: 0.2693240	total: 926ms	remaining: 12.9s
# 67:	learn: 0.2657461	total: 937ms	remaining: 12.8s
# 68:	learn: 0.2640333	total: 949ms	remaining: 12.8s
# 69:	learn: 0.2629060	total: 960ms	remaining: 12.8s
# 70:	learn: 0.2607834	total: 972ms	remaining: 12.7s
# 71:	learn: 0.2584381	total: 985ms	remaining: 12.7s
# 72:	learn: 0.2572067	total: 997ms	remaining: 12.7s
# 73:	learn: 0.2553619	total: 1.01s	remaining: 12.7s
# 74:	learn: 0.2532825	total: 1.03s	remaining: 12.7s
# 75:	learn: 0.2515364	total: 1.05s	remaining: 12.8s
# 76:	learn: 0.2495829	total: 1.07s	remaining: 12.8s
# 77:	learn: 0.2486310	total: 1.08s	remaining: 12.8s
# 78:	learn: 0.2472718	total: 1.1s	remaining: 12.9s
# 79:	learn: 0.2462626	total: 1.12s	remaining: 12.9s
# 80:	learn: 0.2453944	total: 1.14s	remaining: 12.9s
# 81:	learn: 0.2443528	total: 1.15s	remaining: 12.9s
# 82:	learn: 0.2422703	total: 1.17s	remaining: 13s
# 83:	learn: 0.2396725	total: 1.19s	remaining: 12.9s
# 84:	learn: 0.2380075	total: 1.2s	remaining: 12.9s
# 85:	learn: 0.2357944	total: 1.22s	remaining: 13s
# 86:	learn: 0.2346319	total: 1.25s	remaining: 13.1s
# 87:	learn: 0.2329390	total: 1.27s	remaining: 13.1s
# 88:	learn: 0.2308131	total: 1.28s	remaining: 13.2s
# 89:	learn: 0.2290864	total: 1.3s	remaining: 13.1s
# 90:	learn: 0.2279467	total: 1.31s	remaining: 13.1s
# 91:	learn: 0.2270514	total: 1.33s	remaining: 13.1s
# 92:	learn: 0.2259858	total: 1.34s	remaining: 13s
# 93:	learn: 0.2244071	total: 1.35s	remaining: 13.1s
# 94:	learn: 0.2231888	total: 1.37s	remaining: 13s
# 95:	learn: 0.2222746	total: 1.39s	remaining: 13.1s
# 96:	learn: 0.2215817	total: 1.41s	remaining: 13.1s
# 97:	learn: 0.2197414	total: 1.43s	remaining: 13.1s
# 98:	learn: 0.2182149	total: 1.44s	remaining: 13.1s
# 99:	learn: 0.2171490	total: 1.46s	remaining: 13.1s
# 100:	learn: 0.2154892	total: 1.48s	remaining: 13.1s
# 101:	learn: 0.2137679	total: 1.49s	remaining: 13.1s
# 102:	learn: 0.2118050	total: 1.51s	remaining: 13.1s
# 103:	learn: 0.2102513	total: 1.53s	remaining: 13.2s
# 104:	learn: 0.2097034	total: 1.54s	remaining: 13.2s
# 105:	learn: 0.2079473	total: 1.56s	remaining: 13.1s
# 106:	learn: 0.2059499	total: 1.57s	remaining: 13.1s
# 107:	learn: 0.2048920	total: 1.59s	remaining: 13.1s
# 108:	learn: 0.2040678	total: 1.6s	remaining: 13.1s
# 109:	learn: 0.2029645	total: 1.63s	remaining: 13.2s
# 110:	learn: 0.2018581	total: 1.64s	remaining: 13.2s
# 111:	learn: 0.2002907	total: 1.66s	remaining: 13.2s
# 112:	learn: 0.1987162	total: 1.68s	remaining: 13.2s
# 113:	learn: 0.1974258	total: 1.7s	remaining: 13.2s
# 114:	learn: 0.1964776	total: 1.72s	remaining: 13.2s
# 115:	learn: 0.1949766	total: 1.75s	remaining: 13.3s
# 116:	learn: 0.1942453	total: 1.77s	remaining: 13.3s
# 117:	learn: 0.1925142	total: 1.79s	remaining: 13.4s
# 118:	learn: 0.1919995	total: 1.81s	remaining: 13.4s
# 119:	learn: 0.1908120	total: 1.83s	remaining: 13.4s
# 120:	learn: 0.1896545	total: 1.84s	remaining: 13.4s
# 121:	learn: 0.1884545	total: 1.87s	remaining: 13.4s
# 122:	learn: 0.1877000	total: 1.88s	remaining: 13.4s
# 123:	learn: 0.1868128	total: 1.89s	remaining: 13.4s
# 124:	learn: 0.1860159	total: 1.91s	remaining: 13.4s
# 125:	learn: 0.1854255	total: 1.94s	remaining: 13.4s
# 126:	learn: 0.1841607	total: 1.96s	remaining: 13.4s
# 127:	learn: 0.1837120	total: 1.98s	remaining: 13.5s
# 128:	learn: 0.1824497	total: 1.99s	remaining: 13.5s
# 129:	learn: 0.1811035	total: 2.01s	remaining: 13.5s
# 130:	learn: 0.1803434	total: 2.03s	remaining: 13.5s
# 131:	learn: 0.1793055	total: 2.05s	remaining: 13.5s
# 132:	learn: 0.1787925	total: 2.07s	remaining: 13.5s
# 133:	learn: 0.1780031	total: 2.09s	remaining: 13.5s
# 134:	learn: 0.1774704	total: 2.1s	remaining: 13.5s
# 135:	learn: 0.1771654	total: 2.11s	remaining: 13.4s
# 136:	learn: 0.1765295	total: 2.13s	remaining: 13.4s
# 137:	learn: 0.1758751	total: 2.14s	remaining: 13.4s
# 138:	learn: 0.1750771	total: 2.15s	remaining: 13.3s
# 139:	learn: 0.1740196	total: 2.16s	remaining: 13.3s
# 140:	learn: 0.1734409	total: 2.17s	remaining: 13.2s
# 141:	learn: 0.1728264	total: 2.18s	remaining: 13.2s
# 142:	learn: 0.1721347	total: 2.2s	remaining: 13.2s
# 143:	learn: 0.1712710	total: 2.22s	remaining: 13.2s
# 144:	learn: 0.1705797	total: 2.23s	remaining: 13.1s
# 145:	learn: 0.1695341	total: 2.24s	remaining: 13.1s
# 146:	learn: 0.1689959	total: 2.25s	remaining: 13.1s
# 147:	learn: 0.1682998	total: 2.26s	remaining: 13s
# 148:	learn: 0.1677811	total: 2.27s	remaining: 13s
# 149:	learn: 0.1668274	total: 2.28s	remaining: 12.9s
# 150:	learn: 0.1659719	total: 2.29s	remaining: 12.9s
# 151:	learn: 0.1652942	total: 2.31s	remaining: 12.9s
# 152:	learn: 0.1646084	total: 2.32s	remaining: 12.8s
# 153:	learn: 0.1641049	total: 2.33s	remaining: 12.8s
# 154:	learn: 0.1635156	total: 2.34s	remaining: 12.8s
# 155:	learn: 0.1625965	total: 2.35s	remaining: 12.7s
# 156:	learn: 0.1614385	total: 2.36s	remaining: 12.7s
# 157:	learn: 0.1608044	total: 2.37s	remaining: 12.7s
# 158:	learn: 0.1603396	total: 2.39s	remaining: 12.7s
# 159:	learn: 0.1591218	total: 2.4s	remaining: 12.6s
# 160:	learn: 0.1585557	total: 2.42s	remaining: 12.6s
# 161:	learn: 0.1581117	total: 2.43s	remaining: 12.6s
# 162:	learn: 0.1575028	total: 2.44s	remaining: 12.5s
# 163:	learn: 0.1568824	total: 2.45s	remaining: 12.5s
# 164:	learn: 0.1563973	total: 2.46s	remaining: 12.5s
# 165:	learn: 0.1557664	total: 2.47s	remaining: 12.4s
# 166:	learn: 0.1548918	total: 2.48s	remaining: 12.4s
# 167:	learn: 0.1545327	total: 2.49s	remaining: 12.3s
# 168:	learn: 0.1538070	total: 2.5s	remaining: 12.3s
# 169:	learn: 0.1531148	total: 2.52s	remaining: 12.3s
# 170:	learn: 0.1525824	total: 2.53s	remaining: 12.2s
# 171:	learn: 0.1522713	total: 2.54s	remaining: 12.2s
# 172:	learn: 0.1514198	total: 2.55s	remaining: 12.2s
# 173:	learn: 0.1500832	total: 2.56s	remaining: 12.2s
# 174:	learn: 0.1493595	total: 2.58s	remaining: 12.1s
# 175:	learn: 0.1487271	total: 2.59s	remaining: 12.1s
# 176:	learn: 0.1482518	total: 2.6s	remaining: 12.1s
# 177:	learn: 0.1473202	total: 2.61s	remaining: 12s
# 178:	learn: 0.1470832	total: 2.62s	remaining: 12s
# 179:	learn: 0.1463411	total: 2.63s	remaining: 12s
# 180:	learn: 0.1456327	total: 2.64s	remaining: 12s
# 181:	learn: 0.1452986	total: 2.65s	remaining: 11.9s
# 182:	learn: 0.1445080	total: 2.66s	remaining: 11.9s
# 183:	learn: 0.1437836	total: 2.67s	remaining: 11.9s
# 184:	learn: 0.1429382	total: 2.69s	remaining: 11.8s
# 185:	learn: 0.1419663	total: 2.7s	remaining: 11.8s
# 186:	learn: 0.1415796	total: 2.71s	remaining: 11.8s
# 187:	learn: 0.1412352	total: 2.73s	remaining: 11.8s
# 188:	learn: 0.1403212	total: 2.74s	remaining: 11.8s
# 189:	learn: 0.1399191	total: 2.75s	remaining: 11.7s
# 190:	learn: 0.1392181	total: 2.76s	remaining: 11.7s
# 191:	learn: 0.1387942	total: 2.77s	remaining: 11.7s
# 192:	learn: 0.1381371	total: 2.78s	remaining: 11.6s
# 193:	learn: 0.1374671	total: 2.79s	remaining: 11.6s
# 194:	learn: 0.1370842	total: 2.8s	remaining: 11.6s
# 195:	learn: 0.1366603	total: 2.81s	remaining: 11.5s
# 196:	learn: 0.1361532	total: 2.82s	remaining: 11.5s
# 197:	learn: 0.1355877	total: 2.83s	remaining: 11.5s
# 198:	learn: 0.1346498	total: 2.85s	remaining: 11.5s
# 199:	learn: 0.1343088	total: 2.86s	remaining: 11.4s
# 200:	learn: 0.1338955	total: 2.87s	remaining: 11.4s
# 201:	learn: 0.1337336	total: 2.88s	remaining: 11.4s
# 202:	learn: 0.1326908	total: 2.9s	remaining: 11.4s
# 203:	learn: 0.1323374	total: 2.91s	remaining: 11.4s
# 204:	learn: 0.1316775	total: 2.92s	remaining: 11.3s
# 205:	learn: 0.1312394	total: 2.93s	remaining: 11.3s
# 206:	learn: 0.1308809	total: 2.94s	remaining: 11.3s
# 207:	learn: 0.1302731	total: 2.96s	remaining: 11.3s
# 208:	learn: 0.1300474	total: 2.97s	remaining: 11.2s
# 209:	learn: 0.1296896	total: 2.98s	remaining: 11.2s
# 210:	learn: 0.1289044	total: 2.99s	remaining: 11.2s
# 211:	learn: 0.1284410	total: 3s	remaining: 11.2s
# 212:	learn: 0.1281527	total: 3.01s	remaining: 11.1s
# 213:	learn: 0.1275732	total: 3.02s	remaining: 11.1s
# 214:	learn: 0.1267888	total: 3.03s	remaining: 11.1s
# 215:	learn: 0.1264895	total: 3.04s	remaining: 11s
# 216:	learn: 0.1262402	total: 3.05s	remaining: 11s
# 217:	learn: 0.1258397	total: 3.07s	remaining: 11s
# 218:	learn: 0.1252354	total: 3.08s	remaining: 11s
# 219:	learn: 0.1248898	total: 3.09s	remaining: 11s
# 220:	learn: 0.1244704	total: 3.1s	remaining: 10.9s
# 221:	learn: 0.1237408	total: 3.12s	remaining: 10.9s
# 222:	learn: 0.1229634	total: 3.13s	remaining: 10.9s
# 223:	learn: 0.1227021	total: 3.14s	remaining: 10.9s
# 224:	learn: 0.1224838	total: 3.15s	remaining: 10.9s
# 225:	learn: 0.1217563	total: 3.16s	remaining: 10.8s
# 226:	learn: 0.1215132	total: 3.17s	remaining: 10.8s
# 227:	learn: 0.1213178	total: 3.18s	remaining: 10.8s
# 228:	learn: 0.1207440	total: 3.19s	remaining: 10.8s
# 229:	learn: 0.1204691	total: 3.2s	remaining: 10.7s
# 230:	learn: 0.1199155	total: 3.21s	remaining: 10.7s
# 231:	learn: 0.1195204	total: 3.23s	remaining: 10.7s
# 232:	learn: 0.1190591	total: 3.24s	remaining: 10.7s
# 233:	learn: 0.1185209	total: 3.25s	remaining: 10.7s
# 234:	learn: 0.1182743	total: 3.27s	remaining: 10.6s
# 235:	learn: 0.1180482	total: 3.28s	remaining: 10.6s
# 236:	learn: 0.1173226	total: 3.29s	remaining: 10.6s
# 237:	learn: 0.1170088	total: 3.3s	remaining: 10.6s
# 238:	learn: 0.1166289	total: 3.31s	remaining: 10.5s
# 239:	learn: 0.1163288	total: 3.32s	remaining: 10.5s
# 240:	learn: 0.1160497	total: 3.33s	remaining: 10.5s
# 241:	learn: 0.1157355	total: 3.35s	remaining: 10.5s
# 242:	learn: 0.1153565	total: 3.36s	remaining: 10.5s
# 243:	learn: 0.1149458	total: 3.37s	remaining: 10.4s
# 244:	learn: 0.1147361	total: 3.38s	remaining: 10.4s
# 245:	learn: 0.1145492	total: 3.39s	remaining: 10.4s
# 246:	learn: 0.1142326	total: 3.41s	remaining: 10.4s
# 247:	learn: 0.1138540	total: 3.42s	remaining: 10.4s
# 248:	learn: 0.1137025	total: 3.43s	remaining: 10.4s
# 249:	learn: 0.1134123	total: 3.44s	remaining: 10.3s
# 250:	learn: 0.1129940	total: 3.46s	remaining: 10.3s
# 251:	learn: 0.1123817	total: 3.47s	remaining: 10.3s
# 252:	learn: 0.1120351	total: 3.48s	remaining: 10.3s
# 253:	learn: 0.1116236	total: 3.5s	remaining: 10.3s
# 254:	learn: 0.1114705	total: 3.51s	remaining: 10.2s
# 255:	learn: 0.1111184	total: 3.52s	remaining: 10.2s
# 256:	learn: 0.1108274	total: 3.54s	remaining: 10.2s
# 257:	learn: 0.1105949	total: 3.55s	remaining: 10.2s
# 258:	learn: 0.1103435	total: 3.57s	remaining: 10.2s
# 259:	learn: 0.1099682	total: 3.59s	remaining: 10.2s
# 260:	learn: 0.1097875	total: 3.61s	remaining: 10.2s
# 261:	learn: 0.1092558	total: 3.63s	remaining: 10.2s
# 262:	learn: 0.1088144	total: 3.64s	remaining: 10.2s
# 263:	learn: 0.1082993	total: 3.66s	remaining: 10.2s
# 264:	learn: 0.1078459	total: 3.67s	remaining: 10.2s
# 265:	learn: 0.1076145	total: 3.69s	remaining: 10.2s
# 266:	learn: 0.1073329	total: 3.71s	remaining: 10.2s
# 267:	learn: 0.1071319	total: 3.72s	remaining: 10.2s
# 268:	learn: 0.1068682	total: 3.74s	remaining: 10.2s
# 269:	learn: 0.1065620	total: 3.76s	remaining: 10.2s
# 270:	learn: 0.1061477	total: 3.78s	remaining: 10.2s
# 271:	learn: 0.1059894	total: 3.8s	remaining: 10.2s
# 272:	learn: 0.1057393	total: 3.81s	remaining: 10.2s
# 273:	learn: 0.1053559	total: 3.83s	remaining: 10.2s
# 274:	learn: 0.1050481	total: 3.85s	remaining: 10.1s
# 275:	learn: 0.1047114	total: 3.86s	remaining: 10.1s
# 276:	learn: 0.1041467	total: 3.88s	remaining: 10.1s
# 277:	learn: 0.1039228	total: 3.9s	remaining: 10.1s
# 278:	learn: 0.1036815	total: 3.91s	remaining: 10.1s
# 279:	learn: 0.1034897	total: 3.93s	remaining: 10.1s
# 280:	learn: 0.1032754	total: 3.94s	remaining: 10.1s
# 281:	learn: 0.1028603	total: 3.96s	remaining: 10.1s
# 282:	learn: 0.1024159	total: 3.98s	remaining: 10.1s
# 283:	learn: 0.1022690	total: 4s	remaining: 10.1s
# 284:	learn: 0.1020855	total: 4.02s	remaining: 10.1s
# 285:	learn: 0.1018783	total: 4.03s	remaining: 10.1s
# 286:	learn: 0.1016405	total: 4.05s	remaining: 10.1s
# 287:	learn: 0.1013469	total: 4.06s	remaining: 10s
# 288:	learn: 0.1010023	total: 4.08s	remaining: 10s
# 289:	learn: 0.1008781	total: 4.09s	remaining: 10s
# 290:	learn: 0.1006716	total: 4.11s	remaining: 10s
# 291:	learn: 0.1004102	total: 4.13s	remaining: 10s
# 292:	learn: 0.1000644	total: 4.15s	remaining: 10s
# 293:	learn: 0.0998632	total: 4.16s	remaining: 10s
# 294:	learn: 0.0995626	total: 4.18s	remaining: 9.99s
# 295:	learn: 0.0994110	total: 4.2s	remaining: 9.98s
# 296:	learn: 0.0992700	total: 4.21s	remaining: 9.97s
# 297:	learn: 0.0990415	total: 4.22s	remaining: 9.95s
# 298:	learn: 0.0987821	total: 4.24s	remaining: 9.94s
# 299:	learn: 0.0986188	total: 4.26s	remaining: 9.93s
# 300:	learn: 0.0984056	total: 4.27s	remaining: 9.92s
# 301:	learn: 0.0981134	total: 4.29s	remaining: 9.93s
# 302:	learn: 0.0978050	total: 4.31s	remaining: 9.92s
# 303:	learn: 0.0975565	total: 4.33s	remaining: 9.91s
# 304:	learn: 0.0972810	total: 4.34s	remaining: 9.9s
# 305:	learn: 0.0970478	total: 4.36s	remaining: 9.88s
# 306:	learn: 0.0964966	total: 4.37s	remaining: 9.86s
# 307:	learn: 0.0963957	total: 4.38s	remaining: 9.85s
# 308:	learn: 0.0960787	total: 4.39s	remaining: 9.83s
# 309:	learn: 0.0958567	total: 4.41s	remaining: 9.82s
# 310:	learn: 0.0956533	total: 4.42s	remaining: 9.8s
# 311:	learn: 0.0955513	total: 4.44s	remaining: 9.79s
# 312:	learn: 0.0954497	total: 4.46s	remaining: 9.78s
# 313:	learn: 0.0951552	total: 4.47s	remaining: 9.78s
# 314:	learn: 0.0950112	total: 4.49s	remaining: 9.76s
# 315:	learn: 0.0946989	total: 4.5s	remaining: 9.73s
# 316:	learn: 0.0945551	total: 4.51s	remaining: 9.71s
# 317:	learn: 0.0943213	total: 4.52s	remaining: 9.69s
# 318:	learn: 0.0940716	total: 4.53s	remaining: 9.67s
# 319:	learn: 0.0939602	total: 4.54s	remaining: 9.65s
# 320:	learn: 0.0937039	total: 4.55s	remaining: 9.63s
# 321:	learn: 0.0933999	total: 4.56s	remaining: 9.61s
# 322:	learn: 0.0931008	total: 4.57s	remaining: 9.59s
# 323:	learn: 0.0928326	total: 4.59s	remaining: 9.57s
# 324:	learn: 0.0921971	total: 4.61s	remaining: 9.57s
# 325:	learn: 0.0919810	total: 4.62s	remaining: 9.55s
# 326:	learn: 0.0916568	total: 4.63s	remaining: 9.53s
# 327:	learn: 0.0913341	total: 4.64s	remaining: 9.51s
# 328:	learn: 0.0910672	total: 4.65s	remaining: 9.49s
# 329:	learn: 0.0908933	total: 4.66s	remaining: 9.47s
# 330:	learn: 0.0906242	total: 4.67s	remaining: 9.45s
# 331:	learn: 0.0905296	total: 4.68s	remaining: 9.43s
# 332:	learn: 0.0902230	total: 4.7s	remaining: 9.41s
# 333:	learn: 0.0899118	total: 4.71s	remaining: 9.39s
# 334:	learn: 0.0894505	total: 4.72s	remaining: 9.37s
# 335:	learn: 0.0893340	total: 4.73s	remaining: 9.35s
# 336:	learn: 0.0892258	total: 4.74s	remaining: 9.33s
# 337:	learn: 0.0890207	total: 4.75s	remaining: 9.31s
# 338:	learn: 0.0888464	total: 4.77s	remaining: 9.29s
# 339:	learn: 0.0885309	total: 4.78s	remaining: 9.28s
# 340:	learn: 0.0884268	total: 4.79s	remaining: 9.26s
# 341:	learn: 0.0881150	total: 4.8s	remaining: 9.23s
# 342:	learn: 0.0878779	total: 4.81s	remaining: 9.21s
# 343:	learn: 0.0874708	total: 4.82s	remaining: 9.2s
# 344:	learn: 0.0873684	total: 4.83s	remaining: 9.18s
# 345:	learn: 0.0872715	total: 4.84s	remaining: 9.16s
# 346:	learn: 0.0869234	total: 4.86s	remaining: 9.14s
# 347:	learn: 0.0867997	total: 4.87s	remaining: 9.12s
# 348:	learn: 0.0865455	total: 4.88s	remaining: 9.1s
# 349:	learn: 0.0863724	total: 4.89s	remaining: 9.08s
# 350:	learn: 0.0861523	total: 4.9s	remaining: 9.06s
# 351:	learn: 0.0859676	total: 4.91s	remaining: 9.04s
# 352:	learn: 0.0856223	total: 4.92s	remaining: 9.02s
# 353:	learn: 0.0854896	total: 4.94s	remaining: 9.01s
# 354:	learn: 0.0853519	total: 4.95s	remaining: 8.99s
# 355:	learn: 0.0852303	total: 4.96s	remaining: 8.98s
# 356:	learn: 0.0850888	total: 4.98s	remaining: 8.96s
# 357:	learn: 0.0849361	total: 4.99s	remaining: 8.95s
# 358:	learn: 0.0846401	total: 5.01s	remaining: 8.94s
# 359:	learn: 0.0844999	total: 5.02s	remaining: 8.92s
# 360:	learn: 0.0842904	total: 5.04s	remaining: 8.92s
# 361:	learn: 0.0840998	total: 5.05s	remaining: 8.91s
# 362:	learn: 0.0839031	total: 5.07s	remaining: 8.9s
# 363:	learn: 0.0837485	total: 5.08s	remaining: 8.88s
# 364:	learn: 0.0836463	total: 5.1s	remaining: 8.88s
# 365:	learn: 0.0834010	total: 5.12s	remaining: 8.87s
# 366:	learn: 0.0832237	total: 5.14s	remaining: 8.87s
# 367:	learn: 0.0831020	total: 5.16s	remaining: 8.86s
# 368:	learn: 0.0829536	total: 5.17s	remaining: 8.85s
# 369:	learn: 0.0827662	total: 5.19s	remaining: 8.84s
# 370:	learn: 0.0825211	total: 5.21s	remaining: 8.83s
# 371:	learn: 0.0822463	total: 5.22s	remaining: 8.82s
# 372:	learn: 0.0820419	total: 5.24s	remaining: 8.81s
# 373:	learn: 0.0817759	total: 5.26s	remaining: 8.8s
# 374:	learn: 0.0815999	total: 5.27s	remaining: 8.79s
# 375:	learn: 0.0811609	total: 5.29s	remaining: 8.78s
# 376:	learn: 0.0809299	total: 5.3s	remaining: 8.76s
# 377:	learn: 0.0807712	total: 5.33s	remaining: 8.77s
# 378:	learn: 0.0806642	total: 5.34s	remaining: 8.75s
# 379:	learn: 0.0804591	total: 5.36s	remaining: 8.75s
# 380:	learn: 0.0802832	total: 5.38s	remaining: 8.74s
# 381:	learn: 0.0801079	total: 5.39s	remaining: 8.72s
# 382:	learn: 0.0799092	total: 5.41s	remaining: 8.71s
# 383:	learn: 0.0797793	total: 5.42s	remaining: 8.69s
# 384:	learn: 0.0796409	total: 5.43s	remaining: 8.68s
# 385:	learn: 0.0795037	total: 5.44s	remaining: 8.66s
# 386:	learn: 0.0793664	total: 5.46s	remaining: 8.64s
# 387:	learn: 0.0790897	total: 5.47s	remaining: 8.63s
# 388:	learn: 0.0788877	total: 5.49s	remaining: 8.62s
# 389:	learn: 0.0786610	total: 5.5s	remaining: 8.6s
# 390:	learn: 0.0785355	total: 5.51s	remaining: 8.59s
# 391:	learn: 0.0783866	total: 5.53s	remaining: 8.57s
# 392:	learn: 0.0782245	total: 5.54s	remaining: 8.55s
# 393:	learn: 0.0781108	total: 5.55s	remaining: 8.53s
# 394:	learn: 0.0779535	total: 5.56s	remaining: 8.51s
# 395:	learn: 0.0777794	total: 5.57s	remaining: 8.49s
# 396:	learn: 0.0774700	total: 5.58s	remaining: 8.48s
# 397:	learn: 0.0771412	total: 5.59s	remaining: 8.46s
# 398:	learn: 0.0769582	total: 5.6s	remaining: 8.44s
# 399:	learn: 0.0768735	total: 5.62s	remaining: 8.42s
# 400:	learn: 0.0764197	total: 5.63s	remaining: 8.4s
# 401:	learn: 0.0762949	total: 5.64s	remaining: 8.39s
# 402:	learn: 0.0761927	total: 5.66s	remaining: 8.38s
# 403:	learn: 0.0758748	total: 5.67s	remaining: 8.36s
# 404:	learn: 0.0754697	total: 5.68s	remaining: 8.34s
# 405:	learn: 0.0753366	total: 5.69s	remaining: 8.33s
# 406:	learn: 0.0752528	total: 5.7s	remaining: 8.31s
# 407:	learn: 0.0750875	total: 5.71s	remaining: 8.29s
# 408:	learn: 0.0747334	total: 5.72s	remaining: 8.27s
# 409:	learn: 0.0745402	total: 5.74s	remaining: 8.26s
# 410:	learn: 0.0743603	total: 5.75s	remaining: 8.24s
# 411:	learn: 0.0740919	total: 5.76s	remaining: 8.22s
# 412:	learn: 0.0739946	total: 5.77s	remaining: 8.2s
# 413:	learn: 0.0738384	total: 5.78s	remaining: 8.19s
# 414:	learn: 0.0735069	total: 5.79s	remaining: 8.17s
# 415:	learn: 0.0731839	total: 5.81s	remaining: 8.16s
# 416:	learn: 0.0728236	total: 5.83s	remaining: 8.14s
# 417:	learn: 0.0726334	total: 5.84s	remaining: 8.13s
# 418:	learn: 0.0723373	total: 5.85s	remaining: 8.11s
# 419:	learn: 0.0722644	total: 5.86s	remaining: 8.1s
# 420:	learn: 0.0721184	total: 5.88s	remaining: 8.08s
# 421:	learn: 0.0720758	total: 5.89s	remaining: 8.07s
# 422:	learn: 0.0719584	total: 5.91s	remaining: 8.06s
# 423:	learn: 0.0717734	total: 5.93s	remaining: 8.05s
# 424:	learn: 0.0715935	total: 5.94s	remaining: 8.04s
# 425:	learn: 0.0714615	total: 5.96s	remaining: 8.03s
# 426:	learn: 0.0710021	total: 5.98s	remaining: 8.02s
# 427:	learn: 0.0708365	total: 5.99s	remaining: 8.01s
# 428:	learn: 0.0706186	total: 6s	remaining: 7.99s
# 429:	learn: 0.0705127	total: 6.03s	remaining: 7.99s
# 430:	learn: 0.0702951	total: 6.04s	remaining: 7.98s
# 431:	learn: 0.0699794	total: 6.06s	remaining: 7.97s
# 432:	learn: 0.0699311	total: 6.08s	remaining: 7.96s
# 433:	learn: 0.0698967	total: 6.09s	remaining: 7.94s
# 434:	learn: 0.0696923	total: 6.1s	remaining: 7.93s
# 435:	learn: 0.0696317	total: 6.12s	remaining: 7.91s
# 436:	learn: 0.0693829	total: 6.13s	remaining: 7.9s
# 437:	learn: 0.0692222	total: 6.15s	remaining: 7.89s
# 438:	learn: 0.0691188	total: 6.17s	remaining: 7.88s
# 439:	learn: 0.0687886	total: 6.19s	remaining: 7.87s
# 440:	learn: 0.0687198	total: 6.2s	remaining: 7.86s
# 441:	learn: 0.0685347	total: 6.22s	remaining: 7.85s
# 442:	learn: 0.0684836	total: 6.23s	remaining: 7.84s
# 443:	learn: 0.0683379	total: 6.25s	remaining: 7.82s
# 444:	learn: 0.0682084	total: 6.26s	remaining: 7.8s
# 445:	learn: 0.0681575	total: 6.27s	remaining: 7.79s
# 446:	learn: 0.0681225	total: 6.28s	remaining: 7.77s
# 447:	learn: 0.0679766	total: 6.29s	remaining: 7.75s
# 448:	learn: 0.0676340	total: 6.3s	remaining: 7.73s
# 449:	learn: 0.0675323	total: 6.31s	remaining: 7.71s
# 450:	learn: 0.0674205	total: 6.33s	remaining: 7.7s
# 451:	learn: 0.0672538	total: 6.34s	remaining: 7.69s
# 452:	learn: 0.0671631	total: 6.35s	remaining: 7.67s
# 453:	learn: 0.0667350	total: 6.36s	remaining: 7.65s
# 454:	learn: 0.0664514	total: 6.38s	remaining: 7.64s
# 455:	learn: 0.0662193	total: 6.39s	remaining: 7.62s
# 456:	learn: 0.0661132	total: 6.4s	remaining: 7.6s
# 457:	learn: 0.0658512	total: 6.41s	remaining: 7.58s
# 458:	learn: 0.0655522	total: 6.42s	remaining: 7.57s
# 459:	learn: 0.0651879	total: 6.43s	remaining: 7.55s
# 460:	learn: 0.0650565	total: 6.44s	remaining: 7.53s
# 461:	learn: 0.0648526	total: 6.45s	remaining: 7.51s
# 462:	learn: 0.0645798	total: 6.46s	remaining: 7.49s
# 463:	learn: 0.0644783	total: 6.47s	remaining: 7.48s
# 464:	learn: 0.0643069	total: 6.48s	remaining: 7.46s
# 465:	learn: 0.0641338	total: 6.49s	remaining: 7.44s
# 466:	learn: 0.0636163	total: 6.51s	remaining: 7.43s
# 467:	learn: 0.0633469	total: 6.52s	remaining: 7.42s
# 468:	learn: 0.0632675	total: 6.54s	remaining: 7.4s
# 469:	learn: 0.0631359	total: 6.55s	remaining: 7.38s
# 470:	learn: 0.0628583	total: 6.56s	remaining: 7.37s
# 471:	learn: 0.0626622	total: 6.57s	remaining: 7.35s
# 472:	learn: 0.0624899	total: 6.58s	remaining: 7.33s
# 473:	learn: 0.0624138	total: 6.59s	remaining: 7.32s
# 474:	learn: 0.0622458	total: 6.6s	remaining: 7.3s
# 475:	learn: 0.0621983	total: 6.62s	remaining: 7.28s
# 476:	learn: 0.0620561	total: 6.63s	remaining: 7.27s
# 477:	learn: 0.0619509	total: 6.64s	remaining: 7.26s
# 478:	learn: 0.0618050	total: 6.66s	remaining: 7.25s
# 479:	learn: 0.0615867	total: 6.68s	remaining: 7.24s
# 480:	learn: 0.0612217	total: 6.7s	remaining: 7.22s
# 481:	learn: 0.0611628	total: 6.71s	remaining: 7.21s
# 482:	learn: 0.0609939	total: 6.73s	remaining: 7.2s
# 483:	learn: 0.0608084	total: 6.75s	remaining: 7.19s
# 484:	learn: 0.0607871	total: 6.76s	remaining: 7.18s
# 485:	learn: 0.0606869	total: 6.78s	remaining: 7.17s
# 486:	learn: 0.0606173	total: 6.79s	remaining: 7.16s
# 487:	learn: 0.0604853	total: 6.81s	remaining: 7.15s
# 488:	learn: 0.0604496	total: 6.83s	remaining: 7.14s
# 489:	learn: 0.0604112	total: 6.85s	remaining: 7.13s
# 490:	learn: 0.0603865	total: 6.87s	remaining: 7.12s
# 491:	learn: 0.0602325	total: 6.88s	remaining: 7.11s
# 492:	learn: 0.0601494	total: 6.9s	remaining: 7.09s
# 493:	learn: 0.0598112	total: 6.92s	remaining: 7.08s
# 494:	learn: 0.0597189	total: 6.93s	remaining: 7.07s
# 495:	learn: 0.0596091	total: 6.95s	remaining: 7.06s
# 496:	learn: 0.0594373	total: 6.96s	remaining: 7.05s
# 497:	learn: 0.0591715	total: 6.98s	remaining: 7.03s
# 498:	learn: 0.0589217	total: 6.99s	remaining: 7.02s
# 499:	learn: 0.0587830	total: 7.01s	remaining: 7.01s
# 500:	learn: 0.0587015	total: 7.03s	remaining: 7s
# 501:	learn: 0.0585971	total: 7.04s	remaining: 6.99s
# 502:	learn: 0.0584548	total: 7.06s	remaining: 6.97s
# 503:	learn: 0.0583716	total: 7.07s	remaining: 6.96s
# 504:	learn: 0.0581978	total: 7.08s	remaining: 6.94s
# 505:	learn: 0.0579385	total: 7.09s	remaining: 6.92s
# 506:	learn: 0.0578272	total: 7.1s	remaining: 6.91s
# 507:	learn: 0.0577734	total: 7.12s	remaining: 6.89s
# 508:	learn: 0.0576294	total: 7.13s	remaining: 6.87s
# 509:	learn: 0.0574584	total: 7.14s	remaining: 6.86s
# 510:	learn: 0.0574358	total: 7.15s	remaining: 6.84s
# 511:	learn: 0.0573588	total: 7.16s	remaining: 6.82s
# 512:	learn: 0.0572844	total: 7.17s	remaining: 6.81s
# 513:	learn: 0.0571640	total: 7.18s	remaining: 6.79s
# 514:	learn: 0.0570524	total: 7.2s	remaining: 6.78s
# 515:	learn: 0.0569008	total: 7.21s	remaining: 6.76s
# 516:	learn: 0.0567571	total: 7.22s	remaining: 6.75s
# 517:	learn: 0.0565731	total: 7.23s	remaining: 6.73s
# 518:	learn: 0.0564449	total: 7.25s	remaining: 6.71s
# 519:	learn: 0.0561366	total: 7.26s	remaining: 6.7s
# 520:	learn: 0.0560465	total: 7.27s	remaining: 6.68s
# 521:	learn: 0.0559855	total: 7.28s	remaining: 6.67s
# 522:	learn: 0.0559530	total: 7.29s	remaining: 6.65s
# 523:	learn: 0.0558354	total: 7.3s	remaining: 6.63s
# 524:	learn: 0.0557435	total: 7.31s	remaining: 6.61s
# 525:	learn: 0.0554538	total: 7.32s	remaining: 6.6s
# 526:	learn: 0.0551593	total: 7.33s	remaining: 6.58s
# 527:	learn: 0.0550815	total: 7.34s	remaining: 6.56s
# 528:	learn: 0.0549110	total: 7.36s	remaining: 6.55s
# 529:	learn: 0.0548810	total: 7.37s	remaining: 6.54s
# 530:	learn: 0.0548037	total: 7.38s	remaining: 6.52s
# 531:	learn: 0.0547341	total: 7.4s	remaining: 6.51s
# 532:	learn: 0.0545878	total: 7.41s	remaining: 6.49s
# 533:	learn: 0.0543712	total: 7.42s	remaining: 6.47s
# 534:	learn: 0.0542232	total: 7.43s	remaining: 6.46s
# 535:	learn: 0.0541979	total: 7.44s	remaining: 6.44s
# 536:	learn: 0.0539966	total: 7.45s	remaining: 6.43s
# 537:	learn: 0.0539505	total: 7.47s	remaining: 6.42s
# 538:	learn: 0.0538454	total: 7.49s	remaining: 6.4s
# 539:	learn: 0.0536412	total: 7.5s	remaining: 6.39s
# 540:	learn: 0.0535124	total: 7.52s	remaining: 6.38s
# 541:	learn: 0.0532977	total: 7.54s	remaining: 6.37s
# 542:	learn: 0.0531380	total: 7.56s	remaining: 6.36s
# 543:	learn: 0.0529773	total: 7.58s	remaining: 6.35s
# 544:	learn: 0.0529116	total: 7.59s	remaining: 6.34s
# 545:	learn: 0.0528000	total: 7.61s	remaining: 6.33s
# 546:	learn: 0.0526946	total: 7.62s	remaining: 6.31s
# 547:	learn: 0.0526638	total: 7.63s	remaining: 6.3s
# 548:	learn: 0.0525739	total: 7.65s	remaining: 6.28s
# 549:	learn: 0.0525291	total: 7.66s	remaining: 6.27s
# 550:	learn: 0.0524445	total: 7.67s	remaining: 6.25s
# 551:	learn: 0.0524229	total: 7.69s	remaining: 6.24s
# 552:	learn: 0.0522145	total: 7.7s	remaining: 6.22s
# 553:	learn: 0.0520511	total: 7.72s	remaining: 6.21s
# 554:	learn: 0.0519692	total: 7.73s	remaining: 6.2s
# 555:	learn: 0.0518529	total: 7.74s	remaining: 6.18s
# 556:	learn: 0.0517243	total: 7.75s	remaining: 6.17s
# 557:	learn: 0.0514242	total: 7.76s	remaining: 6.15s
# 558:	learn: 0.0513779	total: 7.78s	remaining: 6.13s
# 559:	learn: 0.0512810	total: 7.79s	remaining: 6.12s
# 560:	learn: 0.0511327	total: 7.8s	remaining: 6.1s
# 561:	learn: 0.0510433	total: 7.81s	remaining: 6.08s
# 562:	learn: 0.0509884	total: 7.82s	remaining: 6.07s
# 563:	learn: 0.0509590	total: 7.83s	remaining: 6.05s
# 564:	learn: 0.0508388	total: 7.84s	remaining: 6.04s
# 565:	learn: 0.0504869	total: 7.85s	remaining: 6.02s
# 566:	learn: 0.0503435	total: 7.87s	remaining: 6.01s
# 567:	learn: 0.0502988	total: 7.88s	remaining: 5.99s
# 568:	learn: 0.0502715	total: 7.89s	remaining: 5.98s
# 569:	learn: 0.0500308	total: 7.9s	remaining: 5.96s
# 570:	learn: 0.0498974	total: 7.92s	remaining: 5.95s
# 571:	learn: 0.0498575	total: 7.93s	remaining: 5.93s
# 572:	learn: 0.0496901	total: 7.94s	remaining: 5.92s
# 573:	learn: 0.0496192	total: 7.95s	remaining: 5.9s
# 574:	learn: 0.0495060	total: 7.96s	remaining: 5.88s
# 575:	learn: 0.0493910	total: 7.97s	remaining: 5.87s
# 576:	learn: 0.0492414	total: 7.98s	remaining: 5.85s
# 577:	learn: 0.0490676	total: 7.99s	remaining: 5.83s
# 578:	learn: 0.0490308	total: 8s	remaining: 5.82s
# 579:	learn: 0.0489050	total: 8.01s	remaining: 5.8s
# 580:	learn: 0.0486770	total: 8.03s	remaining: 5.79s
# 581:	learn: 0.0485478	total: 8.04s	remaining: 5.77s
# 582:	learn: 0.0485057	total: 8.05s	remaining: 5.76s
# 583:	learn: 0.0483350	total: 8.07s	remaining: 5.75s
# 584:	learn: 0.0483177	total: 8.08s	remaining: 5.73s
# 585:	learn: 0.0482015	total: 8.09s	remaining: 5.72s
# 586:	learn: 0.0481832	total: 8.1s	remaining: 5.7s
# 587:	learn: 0.0480814	total: 8.12s	remaining: 5.69s
# 588:	learn: 0.0480637	total: 8.13s	remaining: 5.67s
# 589:	learn: 0.0478564	total: 8.14s	remaining: 5.66s
# 590:	learn: 0.0477359	total: 8.15s	remaining: 5.64s
# 591:	learn: 0.0475691	total: 8.16s	remaining: 5.63s
# 592:	learn: 0.0475520	total: 8.17s	remaining: 5.61s
# 593:	learn: 0.0474570	total: 8.2s	remaining: 5.6s
# 594:	learn: 0.0473684	total: 8.21s	remaining: 5.59s
# 595:	learn: 0.0472778	total: 8.23s	remaining: 5.58s
# 596:	learn: 0.0471832	total: 8.25s	remaining: 5.57s
# 597:	learn: 0.0471543	total: 8.28s	remaining: 5.56s
# 598:	learn: 0.0470984	total: 8.29s	remaining: 5.55s
# 599:	learn: 0.0469817	total: 8.31s	remaining: 5.54s
# 600:	learn: 0.0468697	total: 8.33s	remaining: 5.53s
# 601:	learn: 0.0468267	total: 8.34s	remaining: 5.51s
# 602:	learn: 0.0467880	total: 8.36s	remaining: 5.5s
# 603:	learn: 0.0466748	total: 8.37s	remaining: 5.49s
# 604:	learn: 0.0465488	total: 8.39s	remaining: 5.48s
# 605:	learn: 0.0464311	total: 8.41s	remaining: 5.46s
# 606:	learn: 0.0463324	total: 8.42s	remaining: 5.45s
# 607:	learn: 0.0462305	total: 8.44s	remaining: 5.44s
# 608:	learn: 0.0459767	total: 8.45s	remaining: 5.42s
# 609:	learn: 0.0459557	total: 8.46s	remaining: 5.41s
# 610:	learn: 0.0458732	total: 8.47s	remaining: 5.39s
# 611:	learn: 0.0458102	total: 8.48s	remaining: 5.38s
# 612:	learn: 0.0456722	total: 8.49s	remaining: 5.36s
# 613:	learn: 0.0456132	total: 8.5s	remaining: 5.35s
# 614:	learn: 0.0455035	total: 8.52s	remaining: 5.33s
# 615:	learn: 0.0454871	total: 8.53s	remaining: 5.32s
# 616:	learn: 0.0453832	total: 8.54s	remaining: 5.3s
# 617:	learn: 0.0453145	total: 8.55s	remaining: 5.28s
# 618:	learn: 0.0452926	total: 8.56s	remaining: 5.27s
# 619:	learn: 0.0452308	total: 8.57s	remaining: 5.25s
# 620:	learn: 0.0451958	total: 8.59s	remaining: 5.24s
# 621:	learn: 0.0451053	total: 8.6s	remaining: 5.23s
# 622:	learn: 0.0450767	total: 8.61s	remaining: 5.21s
# 623:	learn: 0.0449830	total: 8.62s	remaining: 5.2s
# 624:	learn: 0.0448640	total: 8.64s	remaining: 5.18s
# 625:	learn: 0.0447589	total: 8.65s	remaining: 5.17s
# 626:	learn: 0.0446522	total: 8.66s	remaining: 5.15s
# 627:	learn: 0.0446114	total: 8.67s	remaining: 5.13s
# 628:	learn: 0.0445922	total: 8.68s	remaining: 5.12s
# 629:	learn: 0.0445150	total: 8.69s	remaining: 5.1s
# 630:	learn: 0.0443289	total: 8.7s	remaining: 5.09s
# 631:	learn: 0.0442433	total: 8.71s	remaining: 5.07s
# 632:	learn: 0.0442274	total: 8.72s	remaining: 5.06s
# 633:	learn: 0.0441595	total: 8.73s	remaining: 5.04s
# 634:	learn: 0.0441101	total: 8.74s	remaining: 5.03s
# 635:	learn: 0.0440813	total: 8.75s	remaining: 5.01s
# 636:	learn: 0.0440178	total: 8.77s	remaining: 5s
# 637:	learn: 0.0439348	total: 8.79s	remaining: 4.99s
# 638:	learn: 0.0438665	total: 8.8s	remaining: 4.97s
# 639:	learn: 0.0437658	total: 8.81s	remaining: 4.96s
# 640:	learn: 0.0436708	total: 8.82s	remaining: 4.94s
# 641:	learn: 0.0436561	total: 8.83s	remaining: 4.93s
# 642:	learn: 0.0435683	total: 8.84s	remaining: 4.91s
# 643:	learn: 0.0434256	total: 8.86s	remaining: 4.89s
# 644:	learn: 0.0433199	total: 8.87s	remaining: 4.88s
# 645:	learn: 0.0432127	total: 8.88s	remaining: 4.86s
# 646:	learn: 0.0431232	total: 8.89s	remaining: 4.85s
# 647:	learn: 0.0430386	total: 8.9s	remaining: 4.83s
# 648:	learn: 0.0430246	total: 8.91s	remaining: 4.82s
# 649:	learn: 0.0429118	total: 8.92s	remaining: 4.8s
# 650:	learn: 0.0428620	total: 8.93s	remaining: 4.79s
# 651:	learn: 0.0427698	total: 8.95s	remaining: 4.78s
# 652:	learn: 0.0427064	total: 8.96s	remaining: 4.76s
# 653:	learn: 0.0426239	total: 8.98s	remaining: 4.75s
# 654:	learn: 0.0425331	total: 8.99s	remaining: 4.73s
# 655:	learn: 0.0424168	total: 9s	remaining: 4.72s
# 656:	learn: 0.0423455	total: 9.01s	remaining: 4.7s
# 657:	learn: 0.0422870	total: 9.02s	remaining: 4.69s
# 658:	learn: 0.0422206	total: 9.03s	remaining: 4.67s
# 659:	learn: 0.0421026	total: 9.04s	remaining: 4.66s
# 660:	learn: 0.0420443	total: 9.05s	remaining: 4.64s
# 661:	learn: 0.0420178	total: 9.07s	remaining: 4.63s
# 662:	learn: 0.0419712	total: 9.08s	remaining: 4.61s
# 663:	learn: 0.0419577	total: 9.09s	remaining: 4.6s
# 664:	learn: 0.0418858	total: 9.11s	remaining: 4.59s
# 665:	learn: 0.0417928	total: 9.12s	remaining: 4.57s
# 666:	learn: 0.0416870	total: 9.13s	remaining: 4.56s
# 667:	learn: 0.0416076	total: 9.15s	remaining: 4.55s
# 668:	learn: 0.0415344	total: 9.16s	remaining: 4.53s
# 669:	learn: 0.0414386	total: 9.18s	remaining: 4.52s
# 670:	learn: 0.0413825	total: 9.19s	remaining: 4.51s
# 671:	learn: 0.0413235	total: 9.21s	remaining: 4.5s
# 672:	learn: 0.0413105	total: 9.23s	remaining: 4.48s
# 673:	learn: 0.0412833	total: 9.24s	remaining: 4.47s
# 674:	learn: 0.0412583	total: 9.26s	remaining: 4.46s
# 675:	learn: 0.0412201	total: 9.28s	remaining: 4.45s
# 676:	learn: 0.0411676	total: 9.3s	remaining: 4.44s
# 677:	learn: 0.0410745	total: 9.32s	remaining: 4.42s
# 678:	learn: 0.0409716	total: 9.33s	remaining: 4.41s
# 679:	learn: 0.0408825	total: 9.35s	remaining: 4.4s
# 680:	learn: 0.0407905	total: 9.37s	remaining: 4.39s
# 681:	learn: 0.0407469	total: 9.38s	remaining: 4.37s
# 682:	learn: 0.0406770	total: 9.39s	remaining: 4.36s
# 683:	learn: 0.0405970	total: 9.41s	remaining: 4.35s
# 684:	learn: 0.0405846	total: 9.42s	remaining: 4.33s
# 685:	learn: 0.0405091	total: 9.44s	remaining: 4.32s
# 686:	learn: 0.0404384	total: 9.46s	remaining: 4.31s
# 687:	learn: 0.0403431	total: 9.47s	remaining: 4.29s
# 688:	learn: 0.0401799	total: 9.48s	remaining: 4.28s
# 689:	learn: 0.0401119	total: 9.49s	remaining: 4.26s
# 690:	learn: 0.0400628	total: 9.5s	remaining: 4.25s
# 691:	learn: 0.0399777	total: 9.51s	remaining: 4.23s
# 692:	learn: 0.0399056	total: 9.52s	remaining: 4.22s
# 693:	learn: 0.0398395	total: 9.53s	remaining: 4.2s
# 694:	learn: 0.0397517	total: 9.54s	remaining: 4.19s
# 695:	learn: 0.0396502	total: 9.55s	remaining: 4.17s
# 696:	learn: 0.0395826	total: 9.56s	remaining: 4.16s
# 697:	learn: 0.0395211	total: 9.58s	remaining: 4.14s
# 698:	learn: 0.0395091	total: 9.59s	remaining: 4.13s
# 699:	learn: 0.0393767	total: 9.6s	remaining: 4.11s
# 700:	learn: 0.0393156	total: 9.62s	remaining: 4.1s
# 701:	learn: 0.0392393	total: 9.63s	remaining: 4.09s
# 702:	learn: 0.0392102	total: 9.64s	remaining: 4.07s
# 703:	learn: 0.0390829	total: 9.65s	remaining: 4.06s
# 704:	learn: 0.0390176	total: 9.66s	remaining: 4.04s
# 705:	learn: 0.0389391	total: 9.67s	remaining: 4.03s
# 706:	learn: 0.0388993	total: 9.68s	remaining: 4.01s
# 707:	learn: 0.0388105	total: 9.69s	remaining: 4s
# 708:	learn: 0.0387866	total: 9.7s	remaining: 3.98s
# 709:	learn: 0.0386871	total: 9.71s	remaining: 3.97s
# 710:	learn: 0.0386106	total: 9.73s	remaining: 3.95s
# 711:	learn: 0.0385368	total: 9.74s	remaining: 3.94s
# 712:	learn: 0.0385046	total: 9.75s	remaining: 3.92s
# 713:	learn: 0.0384215	total: 9.76s	remaining: 3.91s
# 714:	learn: 0.0384101	total: 9.78s	remaining: 3.9s
# 715:	learn: 0.0383403	total: 9.79s	remaining: 3.88s
# 716:	learn: 0.0383291	total: 9.8s	remaining: 3.87s
# 717:	learn: 0.0382510	total: 9.81s	remaining: 3.85s
# 718:	learn: 0.0382259	total: 9.82s	remaining: 3.84s
# 719:	learn: 0.0381677	total: 9.84s	remaining: 3.83s
# 720:	learn: 0.0381569	total: 9.85s	remaining: 3.81s
# 721:	learn: 0.0381332	total: 9.86s	remaining: 3.8s
# 722:	learn: 0.0380163	total: 9.87s	remaining: 3.78s
# 723:	learn: 0.0379546	total: 9.88s	remaining: 3.77s
# 724:	learn: 0.0379242	total: 9.89s	remaining: 3.75s
# 725:	learn: 0.0377336	total: 9.91s	remaining: 3.74s
# 726:	learn: 0.0376008	total: 9.92s	remaining: 3.72s
# 727:	learn: 0.0374571	total: 9.93s	remaining: 3.71s
# 728:	learn: 0.0374272	total: 9.95s	remaining: 3.7s
# 729:	learn: 0.0373060	total: 9.97s	remaining: 3.69s
# 730:	learn: 0.0372667	total: 9.99s	remaining: 3.67s
# 731:	learn: 0.0371784	total: 10s	remaining: 3.66s
# 732:	learn: 0.0371083	total: 10s	remaining: 3.65s
# 733:	learn: 0.0370541	total: 10s	remaining: 3.64s
# 734:	learn: 0.0369779	total: 10.1s	remaining: 3.63s
# 735:	learn: 0.0369674	total: 10.1s	remaining: 3.61s
# 736:	learn: 0.0368934	total: 10.1s	remaining: 3.6s
# 737:	learn: 0.0367819	total: 10.1s	remaining: 3.58s
# 738:	learn: 0.0367018	total: 10.1s	remaining: 3.57s
# 739:	learn: 0.0366646	total: 10.1s	remaining: 3.56s
# 740:	learn: 0.0366544	total: 10.1s	remaining: 3.55s
# 741:	learn: 0.0365847	total: 10.2s	remaining: 3.53s
# 742:	learn: 0.0364922	total: 10.2s	remaining: 3.52s
# 743:	learn: 0.0364557	total: 10.2s	remaining: 3.51s
# 744:	learn: 0.0364412	total: 10.2s	remaining: 3.49s
# 745:	learn: 0.0363923	total: 10.2s	remaining: 3.48s
# 746:	learn: 0.0362073	total: 10.2s	remaining: 3.47s
# 747:	learn: 0.0361500	total: 10.3s	remaining: 3.45s
# 748:	learn: 0.0360875	total: 10.3s	remaining: 3.44s
# 749:	learn: 0.0359654	total: 10.3s	remaining: 3.43s
# 750:	learn: 0.0359555	total: 10.3s	remaining: 3.42s
# 751:	learn: 0.0359233	total: 10.3s	remaining: 3.4s
# 752:	learn: 0.0358890	total: 10.3s	remaining: 3.39s
# 753:	learn: 0.0358193	total: 10.4s	remaining: 3.38s
# 754:	learn: 0.0357356	total: 10.4s	remaining: 3.36s
# 755:	learn: 0.0356909	total: 10.4s	remaining: 3.35s
# 756:	learn: 0.0356317	total: 10.4s	remaining: 3.34s
# 757:	learn: 0.0355964	total: 10.4s	remaining: 3.33s
# 758:	learn: 0.0354873	total: 10.4s	remaining: 3.31s
# 759:	learn: 0.0354723	total: 10.4s	remaining: 3.3s
# 760:	learn: 0.0354506	total: 10.5s	remaining: 3.29s
# 761:	learn: 0.0354235	total: 10.5s	remaining: 3.27s
# 762:	learn: 0.0353598	total: 10.5s	remaining: 3.26s
# 763:	learn: 0.0353140	total: 10.5s	remaining: 3.25s
# 764:	learn: 0.0352296	total: 10.5s	remaining: 3.23s
# 765:	learn: 0.0351578	total: 10.5s	remaining: 3.22s
# 766:	learn: 0.0350550	total: 10.6s	remaining: 3.21s
# 767:	learn: 0.0349661	total: 10.6s	remaining: 3.19s
# 768:	learn: 0.0349181	total: 10.6s	remaining: 3.18s
# 769:	learn: 0.0348884	total: 10.6s	remaining: 3.17s
# 770:	learn: 0.0348552	total: 10.6s	remaining: 3.15s
# 771:	learn: 0.0348155	total: 10.6s	remaining: 3.14s
# 772:	learn: 0.0347912	total: 10.7s	remaining: 3.13s
# 773:	learn: 0.0347116	total: 10.7s	remaining: 3.12s
# 774:	learn: 0.0346797	total: 10.7s	remaining: 3.1s
# 775:	learn: 0.0346199	total: 10.7s	remaining: 3.09s
# 776:	learn: 0.0345286	total: 10.7s	remaining: 3.08s
# 777:	learn: 0.0344991	total: 10.7s	remaining: 3.06s
# 778:	learn: 0.0344317	total: 10.8s	remaining: 3.05s
# 779:	learn: 0.0344011	total: 10.8s	remaining: 3.04s
# 780:	learn: 0.0343768	total: 10.8s	remaining: 3.03s
# 781:	learn: 0.0343270	total: 10.8s	remaining: 3.01s
# 782:	learn: 0.0342480	total: 10.8s	remaining: 3s
# 783:	learn: 0.0342073	total: 10.9s	remaining: 2.99s
# 784:	learn: 0.0341956	total: 10.9s	remaining: 2.98s
# 785:	learn: 0.0341853	total: 10.9s	remaining: 2.96s
# 786:	learn: 0.0341259	total: 10.9s	remaining: 2.95s
# 787:	learn: 0.0340442	total: 10.9s	remaining: 2.93s
# 788:	learn: 0.0339662	total: 10.9s	remaining: 2.92s
# 789:	learn: 0.0339148	total: 10.9s	remaining: 2.91s
# 790:	learn: 0.0338510	total: 11s	remaining: 2.89s
# 791:	learn: 0.0338241	total: 11s	remaining: 2.88s
# 792:	learn: 0.0337734	total: 11s	remaining: 2.87s
# 793:	learn: 0.0337458	total: 11s	remaining: 2.85s
# 794:	learn: 0.0336837	total: 11s	remaining: 2.84s
# 795:	learn: 0.0336770	total: 11s	remaining: 2.83s
# 796:	learn: 0.0336026	total: 11.1s	remaining: 2.81s
# 797:	learn: 0.0335392	total: 11.1s	remaining: 2.8s
# 798:	learn: 0.0334768	total: 11.1s	remaining: 2.79s
# 799:	learn: 0.0334153	total: 11.1s	remaining: 2.77s
# 800:	learn: 0.0333483	total: 11.1s	remaining: 2.76s
# 801:	learn: 0.0333224	total: 11.1s	remaining: 2.75s
# 802:	learn: 0.0333103	total: 11.1s	remaining: 2.73s
# 803:	learn: 0.0332690	total: 11.2s	remaining: 2.72s
# 804:	learn: 0.0331746	total: 11.2s	remaining: 2.71s
# 805:	learn: 0.0331486	total: 11.2s	remaining: 2.69s
# 806:	learn: 0.0331236	total: 11.2s	remaining: 2.68s
# 807:	learn: 0.0330846	total: 11.2s	remaining: 2.67s
# 808:	learn: 0.0330320	total: 11.2s	remaining: 2.65s
# 809:	learn: 0.0329892	total: 11.2s	remaining: 2.64s
# 810:	learn: 0.0328219	total: 11.3s	remaining: 2.62s
# 811:	learn: 0.0327979	total: 11.3s	remaining: 2.61s
# 812:	learn: 0.0327572	total: 11.3s	remaining: 2.6s
# 813:	learn: 0.0326976	total: 11.3s	remaining: 2.58s
# 814:	learn: 0.0325399	total: 11.3s	remaining: 2.57s
# 815:	learn: 0.0325221	total: 11.3s	remaining: 2.56s
# 816:	learn: 0.0324819	total: 11.4s	remaining: 2.54s
# 817:	learn: 0.0323331	total: 11.4s	remaining: 2.53s
# 818:	learn: 0.0322970	total: 11.4s	remaining: 2.52s
# 819:	learn: 0.0322218	total: 11.4s	remaining: 2.5s
# 820:	learn: 0.0321444	total: 11.4s	remaining: 2.49s
# 821:	learn: 0.0321097	total: 11.4s	remaining: 2.47s
# 822:	learn: 0.0320720	total: 11.4s	remaining: 2.46s
# 823:	learn: 0.0320199	total: 11.5s	remaining: 2.45s
# 824:	learn: 0.0319952	total: 11.5s	remaining: 2.44s
# 825:	learn: 0.0319587	total: 11.5s	remaining: 2.42s
# 826:	learn: 0.0319282	total: 11.5s	remaining: 2.41s
# 827:	learn: 0.0319056	total: 11.5s	remaining: 2.39s
# 828:	learn: 0.0317666	total: 11.5s	remaining: 2.38s
# 829:	learn: 0.0317322	total: 11.6s	remaining: 2.37s
# 830:	learn: 0.0316720	total: 11.6s	remaining: 2.35s
# 831:	learn: 0.0316334	total: 11.6s	remaining: 2.34s
# 832:	learn: 0.0315650	total: 11.6s	remaining: 2.33s
# 833:	learn: 0.0315591	total: 11.6s	remaining: 2.31s
# 834:	learn: 0.0314683	total: 11.6s	remaining: 2.3s
# 835:	learn: 0.0314225	total: 11.7s	remaining: 2.29s
# 836:	learn: 0.0313926	total: 11.7s	remaining: 2.27s
# 837:	learn: 0.0312959	total: 11.7s	remaining: 2.26s
# 838:	learn: 0.0312837	total: 11.7s	remaining: 2.24s
# 839:	learn: 0.0311631	total: 11.7s	remaining: 2.23s
# 840:	learn: 0.0311069	total: 11.7s	remaining: 2.22s
# 841:	learn: 0.0310873	total: 11.7s	remaining: 2.2s
# 842:	learn: 0.0310437	total: 11.8s	remaining: 2.19s
# 843:	learn: 0.0310340	total: 11.8s	remaining: 2.17s
# 844:	learn: 0.0309986	total: 11.8s	remaining: 2.16s
# 845:	learn: 0.0309694	total: 11.8s	remaining: 2.15s
# 846:	learn: 0.0309243	total: 11.8s	remaining: 2.13s
# 847:	learn: 0.0308598	total: 11.8s	remaining: 2.12s
# 848:	learn: 0.0307539	total: 11.8s	remaining: 2.11s
# 849:	learn: 0.0307353	total: 11.9s	remaining: 2.09s
# 850:	learn: 0.0306745	total: 11.9s	remaining: 2.08s
# 851:	learn: 0.0306420	total: 11.9s	remaining: 2.07s
# 852:	learn: 0.0306043	total: 11.9s	remaining: 2.05s
# 853:	learn: 0.0305747	total: 11.9s	remaining: 2.04s
# 854:	learn: 0.0305530	total: 11.9s	remaining: 2.02s
# 855:	learn: 0.0304885	total: 12s	remaining: 2.01s
# 856:	learn: 0.0303818	total: 12s	remaining: 2s
# 857:	learn: 0.0302721	total: 12s	remaining: 1.98s
# 858:	learn: 0.0302605	total: 12s	remaining: 1.97s
# 859:	learn: 0.0302335	total: 12s	remaining: 1.96s
# 860:	learn: 0.0301687	total: 12.1s	remaining: 1.95s
# 861:	learn: 0.0300650	total: 12.1s	remaining: 1.93s
# 862:	learn: 0.0299668	total: 12.1s	remaining: 1.92s
# 863:	learn: 0.0299338	total: 12.1s	remaining: 1.9s
# 864:	learn: 0.0298701	total: 12.1s	remaining: 1.89s
# 865:	learn: 0.0297772	total: 12.1s	remaining: 1.88s
# 866:	learn: 0.0295524	total: 12.1s	remaining: 1.86s
# 867:	learn: 0.0295191	total: 12.2s	remaining: 1.85s
# 868:	learn: 0.0294517	total: 12.2s	remaining: 1.83s
# 869:	learn: 0.0293636	total: 12.2s	remaining: 1.82s
# 870:	learn: 0.0293140	total: 12.2s	remaining: 1.81s
# 871:	learn: 0.0292631	total: 12.2s	remaining: 1.79s
# 872:	learn: 0.0292027	total: 12.2s	remaining: 1.78s
# 873:	learn: 0.0291584	total: 12.3s	remaining: 1.77s
# 874:	learn: 0.0291047	total: 12.3s	remaining: 1.75s
# 875:	learn: 0.0290717	total: 12.3s	remaining: 1.74s
# 876:	learn: 0.0290510	total: 12.3s	remaining: 1.73s
# 877:	learn: 0.0290330	total: 12.3s	remaining: 1.71s
# 878:	learn: 0.0290095	total: 12.3s	remaining: 1.7s
# 879:	learn: 0.0289347	total: 12.4s	remaining: 1.68s
# 880:	learn: 0.0288743	total: 12.4s	remaining: 1.67s
# 881:	learn: 0.0288504	total: 12.4s	remaining: 1.66s
# 882:	learn: 0.0287929	total: 12.4s	remaining: 1.64s
# 883:	learn: 0.0287167	total: 12.4s	remaining: 1.63s
# 884:	learn: 0.0285092	total: 12.4s	remaining: 1.61s
# 885:	learn: 0.0284743	total: 12.4s	remaining: 1.6s
# 886:	learn: 0.0284233	total: 12.5s	remaining: 1.59s
# 887:	learn: 0.0284123	total: 12.5s	remaining: 1.57s
# 888:	learn: 0.0283398	total: 12.5s	remaining: 1.56s
# 889:	learn: 0.0283270	total: 12.5s	remaining: 1.55s
# 890:	learn: 0.0282971	total: 12.5s	remaining: 1.53s
# 891:	learn: 0.0282537	total: 12.5s	remaining: 1.52s
# 892:	learn: 0.0282371	total: 12.6s	remaining: 1.5s
# 893:	learn: 0.0282123	total: 12.6s	remaining: 1.49s
# 894:	learn: 0.0280182	total: 12.6s	remaining: 1.48s
# 895:	learn: 0.0280035	total: 12.6s	remaining: 1.46s
# 896:	learn: 0.0279892	total: 12.6s	remaining: 1.45s
# 897:	learn: 0.0279352	total: 12.6s	remaining: 1.43s
# 898:	learn: 0.0279192	total: 12.6s	remaining: 1.42s
# 899:	learn: 0.0278734	total: 12.7s	remaining: 1.41s
# 900:	learn: 0.0277936	total: 12.7s	remaining: 1.39s
# 901:	learn: 0.0277389	total: 12.7s	remaining: 1.38s
# 902:	learn: 0.0277053	total: 12.7s	remaining: 1.36s
# 903:	learn: 0.0276766	total: 12.7s	remaining: 1.35s
# 904:	learn: 0.0276358	total: 12.7s	remaining: 1.34s
# 905:	learn: 0.0276260	total: 12.7s	remaining: 1.32s
# 906:	learn: 0.0276098	total: 12.8s	remaining: 1.31s
# 907:	learn: 0.0275825	total: 12.8s	remaining: 1.29s
# 908:	learn: 0.0275382	total: 12.8s	remaining: 1.28s
# 909:	learn: 0.0275135	total: 12.8s	remaining: 1.27s
# 910:	learn: 0.0274616	total: 12.8s	remaining: 1.25s
# 911:	learn: 0.0274324	total: 12.8s	remaining: 1.24s
# 912:	learn: 0.0273837	total: 12.9s	remaining: 1.23s
# 913:	learn: 0.0273081	total: 12.9s	remaining: 1.21s
# 914:	learn: 0.0272697	total: 12.9s	remaining: 1.2s
# 915:	learn: 0.0272420	total: 12.9s	remaining: 1.18s
# 916:	learn: 0.0271980	total: 12.9s	remaining: 1.17s
# 917:	learn: 0.0270345	total: 12.9s	remaining: 1.16s
# 918:	learn: 0.0269973	total: 13s	remaining: 1.14s
# 919:	learn: 0.0269646	total: 13s	remaining: 1.13s
# 920:	learn: 0.0269197	total: 13s	remaining: 1.11s
# 921:	learn: 0.0268930	total: 13s	remaining: 1.1s
# 922:	learn: 0.0268535	total: 13s	remaining: 1.08s
# 923:	learn: 0.0268372	total: 13s	remaining: 1.07s
# 924:	learn: 0.0267850	total: 13.1s	remaining: 1.06s
# 925:	learn: 0.0267809	total: 13.1s	remaining: 1.04s
# 926:	learn: 0.0267583	total: 13.1s	remaining: 1.03s
# 927:	learn: 0.0267202	total: 13.1s	remaining: 1.01s
# 928:	learn: 0.0267049	total: 13.1s	remaining: 1s
# 929:	learn: 0.0266605	total: 13.1s	remaining: 988ms
# 930:	learn: 0.0266300	total: 13.1s	remaining: 974ms
# 931:	learn: 0.0266075	total: 13.2s	remaining: 960ms
# 932:	learn: 0.0265898	total: 13.2s	remaining: 946ms
# 933:	learn: 0.0265558	total: 13.2s	remaining: 932ms
# 934:	learn: 0.0265039	total: 13.2s	remaining: 918ms
# 935:	learn: 0.0264703	total: 13.2s	remaining: 904ms
# 936:	learn: 0.0264533	total: 13.2s	remaining: 890ms
# 937:	learn: 0.0264037	total: 13.2s	remaining: 876ms
# 938:	learn: 0.0263853	total: 13.3s	remaining: 862ms
# 939:	learn: 0.0263425	total: 13.3s	remaining: 848ms
# 940:	learn: 0.0263209	total: 13.3s	remaining: 833ms
# 941:	learn: 0.0262995	total: 13.3s	remaining: 819ms
# 942:	learn: 0.0262703	total: 13.3s	remaining: 805ms
# 943:	learn: 0.0262285	total: 13.3s	remaining: 791ms
# 944:	learn: 0.0262005	total: 13.4s	remaining: 777ms
# 945:	learn: 0.0261703	total: 13.4s	remaining: 763ms
# 946:	learn: 0.0260095	total: 13.4s	remaining: 749ms
# 947:	learn: 0.0258909	total: 13.4s	remaining: 735ms
# 948:	learn: 0.0258548	total: 13.4s	remaining: 721ms
# 949:	learn: 0.0257729	total: 13.4s	remaining: 707ms
# 950:	learn: 0.0257562	total: 13.4s	remaining: 693ms
# 951:	learn: 0.0257357	total: 13.5s	remaining: 679ms
# 952:	learn: 0.0257102	total: 13.5s	remaining: 665ms
# 953:	learn: 0.0256961	total: 13.5s	remaining: 651ms
# 954:	learn: 0.0256381	total: 13.5s	remaining: 636ms
# 955:	learn: 0.0255726	total: 13.5s	remaining: 622ms
# 956:	learn: 0.0255478	total: 13.5s	remaining: 608ms
# 957:	learn: 0.0254993	total: 13.6s	remaining: 594ms
# 958:	learn: 0.0254575	total: 13.6s	remaining: 580ms
# 959:	learn: 0.0254296	total: 13.6s	remaining: 566ms
# 960:	learn: 0.0253827	total: 13.6s	remaining: 552ms
# 961:	learn: 0.0253470	total: 13.6s	remaining: 538ms
# 962:	learn: 0.0253075	total: 13.6s	remaining: 524ms
# 963:	learn: 0.0252817	total: 13.6s	remaining: 510ms
# 964:	learn: 0.0252317	total: 13.7s	remaining: 496ms
# 965:	learn: 0.0251566	total: 13.7s	remaining: 481ms
# 966:	learn: 0.0251319	total: 13.7s	remaining: 467ms
# 967:	learn: 0.0251083	total: 13.7s	remaining: 453ms
# 968:	learn: 0.0250753	total: 13.7s	remaining: 439ms
# 969:	learn: 0.0250480	total: 13.7s	remaining: 425ms
# 970:	learn: 0.0250407	total: 13.7s	remaining: 411ms
# 971:	learn: 0.0250285	total: 13.8s	remaining: 397ms
# 972:	learn: 0.0250052	total: 13.8s	remaining: 382ms
# 973:	learn: 0.0249586	total: 13.8s	remaining: 368ms
# 974:	learn: 0.0249521	total: 13.8s	remaining: 354ms
# 975:	learn: 0.0249486	total: 13.8s	remaining: 340ms
# 976:	learn: 0.0249258	total: 13.8s	remaining: 326ms
# 977:	learn: 0.0249195	total: 13.9s	remaining: 312ms
# 978:	learn: 0.0248923	total: 13.9s	remaining: 297ms
# 979:	learn: 0.0248688	total: 13.9s	remaining: 283ms
# 980:	learn: 0.0248177	total: 13.9s	remaining: 269ms
# 981:	learn: 0.0247777	total: 13.9s	remaining: 255ms
# 982:	learn: 0.0247506	total: 13.9s	remaining: 241ms
# 983:	learn: 0.0247286	total: 13.9s	remaining: 227ms
# 984:	learn: 0.0246920	total: 14s	remaining: 213ms
# 985:	learn: 0.0246507	total: 14s	remaining: 198ms
# 986:	learn: 0.0246143	total: 14s	remaining: 184ms
# 987:	learn: 0.0245415	total: 14s	remaining: 170ms
# 988:	learn: 0.0244719	total: 14s	remaining: 156ms
# 989:	learn: 0.0244251	total: 14s	remaining: 142ms
# 990:	learn: 0.0244170	total: 14.1s	remaining: 128ms
# 991:	learn: 0.0243745	total: 14.1s	remaining: 114ms
# 992:	learn: 0.0243463	total: 14.1s	remaining: 99.4ms
# 993:	learn: 0.0242433	total: 14.1s	remaining: 85.2ms
# 994:	learn: 0.0242249	total: 14.1s	remaining: 71ms
# 995:	learn: 0.0241845	total: 14.1s	remaining: 56.8ms
# 996:	learn: 0.0241498	total: 14.2s	remaining: 42.6ms
# 997:	learn: 0.0241391	total: 14.2s	remaining: 28.4ms
# 998:	learn: 0.0241061	total: 14.2s	remaining: 14.2ms
# 999:	learn: 0.0240973	total: 14.2s	remaining: 0us
#                   Accuracy  Precision  Train time  Predict time   run_ID
# RandomForest_d12  0.965708   0.946245    1.303303      0.071106  Initial
# KNNeighbors_2     0.955199   0.921311    0.088194      0.157045  Initial
# MLPerceptron      0.847345   0.770196    4.927304      0.013991  Initial
# SVC linear        0.846792   0.772990   21.397350      0.162816  Initial
# AdaBoost          0.892699   0.834792    0.812549      0.036979  Initial
# XGBoost           0.991704   0.985255    1.034882      0.000000  Initial
# CatBoost          0.991150   0.986190   15.913415      0.014991  Initial

# %% [markdown]
# ## 5. Plot and Compare Performance of the Learners.

# %%
#Print and compare Learner performance in grouped bar chart format

def PlotGroupedBarChart(group_list, agent_list, scores):
   
    agent_scores = []
    rects = []
    labels = group_list # bar chart groups
    num_labels = len(labels) + 1

    num_agents = len(agent_list) + 1
    num_bars = num_labels * num_agents
    bar_width = 3 / num_bars
    width = .35
    
    plt.rcParams['figure.figsize'] = [14,6]

    x = np.arange(len(labels))  # the label locations

    fig, ax = plt.subplots()
    num_bars = len(agent_list)
    bar_posn = 0
    for agent in agent_list:
        agent_scores = [scores.loc[agent, labels[0]], scores.loc[agent, labels[1]]]
        rects.append(ax.bar(x - width/2  + bar_width * bar_posn, agent_scores, bar_width, label=agent))
        bar_posn += 1
    
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Percent Score')
    ax.set_title('Performance Scores by Metric and Learner')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    #plt.legend(loc = 'lower right')
    fig.tight_layout()
    plt.show()
    
#Run the plot function to compare performance of the Learners.

metrics = ['Accuracy', 'Precision']
agents  = learner_stats.index.tolist()

PlotGroupedBarChart(metrics, agents, learner_stats)

print()
print('XGB feature evaluation')
xgb = XGBClassifier()
xgb.fit(X_test,y_test)
print(xgb.feature_importances_)
list(X_test.columns)
# Out:
# XGB feature evaluation
# [0.01171482 0.04981288 0.01286996 0.01274128 0.02222755 0.01208906
#  0.02766142 0.05122189 0.40544194 0.05434017 0.01564863 0.01771356
#  0.00623804 0.01049662 0.00798807 0.0234896  0.002871   0.10103785
#  0.00973896 0.00893131 0.04814827 0.00840023 0.0048731  0.01215989
#  0.01424541 0.00837262 0.0038688  0.035657  ]
# ['stock_price_at_STO_offer',
#  'STO_strike',
#  'STO_days_long',
#  'STO_offer_ARR',
#  'stock_price_at_open',
#  'STO_ask_fee%',
#  'STO_offer_strike_delta%',
#  '45 day SMA',
#  '30 day SMA',
#  '15 day SMA',
#  '10 day SMA',
#  'Yearly Min',
#  'Yearly Max',
#  '1 days old',
#  '2 days old',
#  '3 days old',
#  '4 days old',
#  '5 days old',
#  'RSI',
#  'MFI',
#  'MACD',
#  '45 day vel',
#  '30 day vel',
#  '15 day vel',
#  '10 day vel',
#  '5 day vel',
#  '2 day vel',
#  'ER - Expiry']

# %% [markdown]
# Refer to the performance chart above to answer these questions:
#
# Evaluation Questions:
# - What is the difference between accuracy and precision? What other performance metrics might be useful here?
# - Which Learner performed best on both metrics?
# - Comparing RandomForest Learners, what do the suffixes mean?
# - Whic RandomForest did better? Why?
# - What problems would you expect to see if we continued increasing the d parameter?
# - How can you find the best value for the d parameter?
# - Do the same comparison and analysis for the KNNeighbors numeric suffix.
# - Why did RandomForest and KNNeighbors perform so much better than MLPerceptron and SVC?
# - Based on the performance parameters, would you consider this exercise to be linear, nonlinear, or other? Why, why not?
#
# Code Questions:
# - Change the parameter suffixes and corresponding parameters for KNNeighbor and RandomForest. Explain the results.
# - Test another type of classifier. Predict the results for that classifier, then run it and compare to your prediction.
# - Change the parameters for SVC and MLP. Can you improve their performance with different parameters?
# - Change the y axis of the plot to expand the performance differences of the Learners. Is that better, or just deceptive?

# %%
#Run the plot function to compare execution time of the Learners.

#Plot execution time metrics
exec_times = ['Train time', 'Predict time']

PlotGroupedBarChart(exec_times, agents, learner_stats)

# %% [markdown]
# Refer to the chart above to answer these questions about execution times.
#
# Evaluation Questions:
# - Why does SVC Linear take so long to train?
# - Why does KNNeighbors train so quickly?
# - Why does RandomForest train time increase as the d parameter increases?
# - Why is prediction time so much faster than train time for all Learners?
# - Which is more important - train time or prediction time? Why? What circumstances?
# - What circumstances or requirements might change the relative importance of train time vs. prediciton time?
# - Given the execution times above, can you predict how train time will change as the training data set increases? Why?
#
# Code Questions:
# - In the chart, execution times are not well displayed. Change the chart to improve their display.
# - Which data sets are used for training?
# - Make those data sets 50% smaller, then 90% smaller, then rerun the Learners and plot the results.
# - How do the results change with the smaller data sets? Why?

# %% [markdown]
# ## Congratulations, You trained and compared several Learners.

# %% [markdown]
# Congratulations! You just trained several Learners to pick winning stock option trades. Now, you are almost ready to make a fortune in the stock market. But, first... consider these questions:
#
# - How can you improve the feature set?
# - Which Learner(s) would you choose? Why?
# - How can you gain more confidence in your trader?
# - What is your goal? Single profitable trades, or a portfolio of trades? What's the difference?
#
# Tune into the next exciting notebook to explore questions of maximizing portfolio results for options trading.
#
# Wishing you only profitable trades and good learning,
#
# Richard Barrett
#
# richard at rbshomes dot com.
# 925.858.9017
#
# P.S. I want to hear about your adventures in Machine Learning, your questions and comments about stock option trading, and especially your specific applications for machine learning. Just shoot me an email, a text, or even call.
